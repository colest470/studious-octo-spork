# %%
begin
    using Images

    image = load("./assets/download.jpeg")
    println(size(image))
end
# Out:
# ArgumentError: No file exists at given path: /assets/download.jpeg
#
#
#
# Stacktrace:
#
#  [1] checkpath_load
#
#    @ ~/.julia/packages/FileIO/9lYsu/src/loadsave.jl:167 [inlined]
#
#  [2] load(::String; options::@Kwargs{})
#
#    @ FileIO ~/.julia/packages/FileIO/9lYsu/src/loadsave.jl:110
#
#  [3] load(::String)
#
#    @ FileIO ~/.julia/packages/FileIO/9lYsu/src/loadsave.jl:109
#
#  [4] top-level scope
#
#    @ ~/Documents/convolutionalJulia/.ipynb_checkpoints/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sZmlsZQ==.jl:4
